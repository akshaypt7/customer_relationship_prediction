# %% [markdown]
# <a href="https://colab.research.google.com/github/akshaypt7/customer_relationship_prediction/blob/main/KDD_cup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_train = pd.read_csv('/content/drive/MyDrive/KDD_cup/orange_small_train.data', sep='\t')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_train.shape
# Out:
# (50000, 230)

# %%
df_train.head()
# Out:
#    Var1  Var2  Var3  Var4  Var5  ...  Var226   Var227         Var228  Var229  Var230
# 0   NaN   NaN   NaN   NaN   NaN  ...    xb3V     RAYp  F2FyR07IdsN7I     NaN     NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...    fKCe     RAYp  F2FyR07IdsN7I     NaN     NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...    Qu4f  02N6s8f  ib5G6X1eUxUn6    am7c     NaN
# 3   NaN   NaN   NaN   NaN   NaN  ...    FSa2     RAYp  F2FyR07IdsN7I     NaN     NaN
# 4   NaN   NaN   NaN   NaN   NaN  ...    FSa2     RAYp  F2FyR07IdsN7I    mj86     NaN
#
# [5 rows x 230 columns]

# %%
test = pd.read_table('/content/drive/MyDrive/KDD_cup/orange_small_test.data')
test.head()
# Out:
#    Var1  Var2  Var3  Var4  ...  Var227               Var228  Var229  Var230
# 0   NaN   NaN   NaN   NaN  ...    ZI9m     R4y5gQQWY8OodqDV     NaN     NaN
# 1   NaN   NaN   NaN   NaN  ...    RAYp        F2FyR07IdsN7I     NaN     NaN
# 2   NaN   NaN   NaN   NaN  ...    RAYp        F2FyR07IdsN7I     NaN     NaN
# 3   NaN   NaN   NaN   NaN  ...    RAYp  TCU50_Yjmm6GIBZ0lL_    am7c     NaN
# 4   NaN   NaN   NaN   NaN  ...    ZI9m           iyHGyLCEkQ    am7c     NaN
#
# [5 rows x 230 columns]

# %%
appetency =pd.read_table('/content/drive/MyDrive/KDD_cup/orange_small_train_appetency.labels',header = None).loc[:, 0].astype('category')
appetency.head()
# Out:
# 0   -1
# 1   -1
# 2   -1
# 3   -1
# 4   -1
# Name: 0, dtype: category
# Categories (2, int64): [-1, 1]

# %%
upselling= pd.read_table('/content/drive/MyDrive/KDD_cup/orange_small_train_upselling.labels', header = None).loc[:, 0].astype('category')
upselling.head()
# Out:
# 0   -1
# 1   -1
# 2   -1
# 3   -1
# 4   -1
# Name: 0, dtype: category
# Categories (2, int64): [-1, 1]

# %%
churn = pd.read_table('/content/drive/MyDrive/KDD_cup/orange_small_train_churn.labels', header = None).loc[:, 0].astype('category')
churn.head()
# Out:
# 0   -1
# 1    1
# 2   -1
# 3   -1
# 4   -1
# Name: 0, dtype: category
# Categories (2, int64): [-1, 1]

# %% [markdown]
# ### Preprocessing

# %%
from IPython.display import display, HTML

def pretty_print(df):
    return display( HTML( df.to_html().replace("\\n","<br>") ) )
def tbl_report(tbl, cols=None, card=10):
    print("Table Shape", tbl.shape)
    dtypes = tbl.dtypes
    nulls = []
    uniques = []
    numuniques = []
    vcs = []
    for col in dtypes.index:
        n = tbl[col].isnull().sum()
        nulls.append(n)
        strdtcol = str(dtypes[col])
        #if strdtcol == 'object' or strdtcol[0:3] == 'int' or strdtcol[0:3] == 'int':
        #print(strdtcol)
        uniqs = tbl[col].unique()
        uniquenums = uniqs.shape[0]
        if uniquenums < card: # low cardinality
            valcounts = pd.value_counts(tbl[col], dropna=False)
            vc = "\n".join(["{}:{}".format(k,v) for k, v in valcounts.items()])
        else:
            vc='HC' # high cardinality
        uniques.append(uniqs)
        numuniques.append(uniquenums)
        vcs.append(vc)
    nullseries = pd.Series(nulls, index=dtypes.index)
    uniqueseries = pd.Series(uniques, index=dtypes.index)
    numuniqueseries = pd.Series(numuniques, index=dtypes.index)
    vcseries = pd.Series(vcs, index=dtypes.index)
    df = pd.concat([dtypes, nullseries, uniqueseries, numuniqueseries, vcseries], axis=1)
    df.columns = ['dtype', 'nulls', 'uniques', 'num_uniques', 'value_counts']
    if cols:
        return pretty_print(df[cols])
    return pretty_print(df)

# %%
# This returns Dataframe instead of printing

from IPython.display import display, HTML

def pretty_print(df):
    return display( HTML( df.to_html().replace("\\n","<br>") ) )
def tbl_report(tbl, cols=None, card=10):
    print("Table Shape", tbl.shape)
    dtypes = tbl.dtypes
    nulls = []
    uniques = []
    numuniques = []
    vcs = []
    for col in dtypes.index:
        n = tbl[col].isnull().sum()
        nulls.append(n)
        strdtcol = str(dtypes[col])
        #if strdtcol == 'object' or strdtcol[0:3] == 'int' or strdtcol[0:3] == 'int':
        #print(strdtcol)
        uniqs = tbl[col].unique()
        uniquenums = uniqs.shape[0]
        if uniquenums < card: # low cardinality
            valcounts = pd.value_counts(tbl[col], dropna=False)
            vc = "\n".join(["{}:{}".format(k,v) for k, v in valcounts.items()])
        else:
            vc='HC' # high cardinality
        uniques.append(uniqs)
        numuniques.append(uniquenums)
        vcs.append(vc)
    nullseries = pd.Series(nulls, index=dtypes.index)
    uniqueseries = pd.Series(uniques, index=dtypes.index)
    numuniqueseries = pd.Series(numuniques, index=dtypes.index)
    vcseries = pd.Series(vcs, index=dtypes.index)
    df = pd.concat([dtypes, nullseries, uniqueseries, numuniqueseries, vcseries], axis=1)
    df.columns = ['dtype', 'nulls', 'uniques', 'num_uniques', 'value_counts']
    if cols:
        return (df[cols])
    return (df)

# %%
df_train.head()
# Out:
#    Var1  Var2  Var3  Var4  Var5  ...  Var226   Var227         Var228  Var229  Var230
# 0   NaN   NaN   NaN   NaN   NaN  ...    xb3V     RAYp  F2FyR07IdsN7I     NaN     NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...    fKCe     RAYp  F2FyR07IdsN7I     NaN     NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...    Qu4f  02N6s8f  ib5G6X1eUxUn6    am7c     NaN
# 3   NaN   NaN   NaN   NaN   NaN  ...    FSa2     RAYp  F2FyR07IdsN7I     NaN     NaN
# 4   NaN   NaN   NaN   NaN   NaN  ...    FSa2     RAYp  F2FyR07IdsN7I    mj86     NaN
#
# [5 rows x 230 columns]

# %%
tbl_report(df_train, cols=['dtype', 'nulls', 'num_uniques', 'value_counts'])

# %%
df_table = tbl_report(df_train, cols=['dtype', 'nulls', 'num_uniques', 'value_counts']) # Using the second tbl_report function


df_table['dtype'].value_counts()
# Out:
# Table Shape (50000, 230)
# float64    191
# object      38
# int64        1
# Name: dtype, dtype: int64

# %%
df_float = df_table[df_table['dtype']== 'float64']
df_float.shape
# Out:
# (191, 4)

# %%
df_float[df_float['nulls'] > 45000 ].shape # we have 18 columns (type:float) that have more 90% nulls
# Out:
# (18, 4)

# %%
df_object = df_table[df_table['dtype']== 'object']

df_object[df_object['nulls'] > 45000 ].shape # we have 4 columns (type:object)  that have more 90% nulls
# Out:
# (4, 4)

# %%
#Replacing NAN values by mean
df_train = df_train.fillna(df_train.mean())

# %%
df_train
# Out:
#             Var1      Var2        Var3      Var4          Var5         Var6  \
# 0      11.487179  0.004029  425.298387  0.125396  238793.32885  1526.000000
# 1      11.487179  0.004029  425.298387  0.125396  238793.32885   525.000000
# 2      11.487179  0.004029  425.298387  0.125396  238793.32885  5236.000000
# 3      11.487179  0.004029  425.298387  0.125396  238793.32885  1326.437116
# 4      11.487179  0.004029  425.298387  0.125396  238793.32885  1029.000000
# ...          ...       ...         ...       ...           ...          ...
# 49995  11.487179  0.004029  425.298387  0.125396  238793.32885   357.000000
# 49996  11.487179  0.004029  425.298387  0.125396  238793.32885  1078.000000
# 49997  11.487179  0.004029  425.298387  0.125396  238793.32885  2807.000000
# 49998  11.487179  0.004029  425.298387  0.000000  238793.32885  1326.437116
# 49999  11.487179  0.004029  425.298387  0.125396  238793.32885  1694.000000
#
#            Var7  Var8       Var9          Var10  ...   Var221   Var222  \
# 0      7.000000   NaN  48.145299  392605.656355  ...     oslk  fXVEsaq
# 1      0.000000   NaN  48.145299  392605.656355  ...     oslk  2Kb5FSF
# 2      7.000000   NaN  48.145299  392605.656355  ...  Al6ZaUT  NKv4yOc
# 3      0.000000   NaN  48.145299  392605.656355  ...     oslk  CE7uk3u
# 4      7.000000   NaN  48.145299  392605.656355  ...     oslk  1J2cvxe
# ...         ...   ...        ...            ...  ...      ...      ...
# 49995  0.000000   NaN  48.145299  392605.656355  ...     oslk  EROH7Cg
# 49996  0.000000   NaN  48.145299  392605.656355  ...     oslk  GfSQowC
# 49997  7.000000   NaN  48.145299  392605.656355  ...     oslk  dh6qI2t
# 49998  6.809496   NaN  48.145299  392605.656355  ...     oslk  2fF2Oqu
# 49999  7.000000   NaN  48.145299  392605.656355  ...     oslk  IIvC99a
#
#            Var223  Var224  Var225  Var226   Var227               Var228  \
# 0      jySVZNlOJy     NaN     NaN    xb3V     RAYp        F2FyR07IdsN7I
# 1      LM8l689qOp     NaN     NaN    fKCe     RAYp        F2FyR07IdsN7I
# 2      jySVZNlOJy     NaN    kG3k    Qu4f  02N6s8f        ib5G6X1eUxUn6
# 3      LM8l689qOp     NaN     NaN    FSa2     RAYp        F2FyR07IdsN7I
# 4      LM8l689qOp     NaN    kG3k    FSa2     RAYp        F2FyR07IdsN7I
# ...           ...     ...     ...     ...      ...                  ...
# 49995  LM8l689qOp     NaN     NaN    7FJQ     RAYp        F2FyR07IdsN7I
# 49996  LM8l689qOp     NaN    kG3k    FSa2     RAYp              55YFVY9
# 49997  LM8l689qOp     NaN    ELof    fKCe     RAYp  TCU50_Yjmm6GIBZ0lL_
# 49998  LM8l689qOp     NaN     NaN    FSa2     RAYp        F2FyR07IdsN7I
# 49999  LM8l689qOp     NaN     NaN    xb3V     RAYp        F2FyR07IdsN7I
#
#        Var229  Var230
# 0         NaN     NaN
# 1         NaN     NaN
# 2        am7c     NaN
# 3         NaN     NaN
# 4        mj86     NaN
# ...       ...     ...
# 49995     NaN     NaN
# 49996    am7c     NaN
# 49997     NaN     NaN
# 49998     NaN     NaN
# 49999     NaN     NaN
#
# [50000 rows x 230 columns]

# %%
df_table = tbl_report(df_train, cols=['dtype', 'nulls', 'num_uniques', 'value_counts'])
df_table.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6ea41746e757> in <module>
# ----> 1 df_table = tbl_report(df_train, cols=['dtype', 'nulls', 'num_uniques', 'value_counts'])
#       2 df_table.head()
#
# NameError: name 'tbl_report' is not defined

# %%
droplist = []

# dropping columns from 190 - 230 (columns that are object)

for i in range(df_train.shape[1]-40, df_train.shape[1]+1):
    value = 0
    value = 'Var{}'.format(i)
    droplist.append(value)

# %%
df_train['Var227'].unique()
# Out:
# array(['RAYp', '02N6s8f', '6fzt', 'ZI9m', 'nIGXDli', 'vJ_w8kB', 'nIGjgSB'],
#       dtype=object)

# %%
df_train = df_train.drop(droplist,axis=1)
df_train = df_train.fillna(0)

# %%
# Table report after dropping columns and filling na with 0
tbl_report(df_train, cols=['dtype', 'nulls', 'num_uniques', 'value_counts'])
# Out:
# Table Shape (50000, 189)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>dtype</th>
#       <th>nulls</th>
#       <th>num_uniques</th>
#       <th>value_counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Var1</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>19</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var2</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>3</td>
#       <td>0.0040290088638195:48759<br>0.0:1240<br>5.0:1</td>
#     </tr>
#     <tr>
#       <th>Var3</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>147</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var4</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>5</td>
#       <td>0.12539582013932868:48421<br>0.0:1561<br>9.0:15<br>18.0:2<br>27.0:1</td>
#     </tr>
#     <tr>
#       <th>Var5</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>572</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var6</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>1487</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var7</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>9</td>
#       <td>7.0:23530<br>0.0:13090<br>6.809495962753874:5539<br>14.0:5049<br>21.0:1825<br>28.0:703<br>35.0:262<br>42.0:1<br>140.0:1</td>
#     </tr>
#     <tr>
#       <th>Var8</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0.0:50000</td>
#     </tr>
#     <tr>
#       <th>Var9</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>101</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var10</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>535</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var11</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>6</td>
#       <td>8.625806451612902:48760<br>8.0:1169<br>16.0:52<br>24.0:14<br>32.0:3<br>40.0:2</td>
#     </tr>
#     <tr>
#       <th>Var12</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>23</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var13</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>2635</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var14</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>20</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var15</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0.0:50000</td>
#     </tr>
#     <tr>
#       <th>Var16</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>598</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var17</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>38</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var18</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>27</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var19</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>5</td>
#       <td>0.24509183027232426:48421<br>0.0:1543<br>9.0:32<br>27.0:3<br>18.0:1</td>
#     </tr>
#     <tr>
#       <th>Var20</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0.0:50000</td>
#     </tr>
#     <tr>
#       <th>Var21</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>735</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var22</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>736</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var23</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>30</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var24</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>94</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var25</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>272</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var26</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>5</td>
#       <td>0.07061197041022192:48513<br>0.0:1457<br>3.0:26<br>6.0:3<br>9.0:1</td>
#     </tr>
#     <tr>
#       <th>Var27</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>4</td>
#       <td>0.02824478816408877:48513<br>0.0:1467<br>2.0:19<br>4.0:1</td>
#     </tr>
#     <tr>
#       <th>Var28</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>4168</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var29</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>3</td>
#       <td>0.022792022792022793:49298<br>0.0:694<br>2.0:8</td>
#     </tr>
#     <tr>
#       <th>Var30</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>14</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var31</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0.0:50000</td>
#     </tr>
#     <tr>
#       <th>Var32</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0.0:50000</td>
#     </tr>
#     <tr>
#       <th>Var33</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>299</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var34</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>7</td>
#       <td>1.1732473811442385:48759<br>0.0:1126<br>8.0:74<br>16.0:24<br>24.0:11<br>32.0:5<br>56.0:1</td>
#     </tr>
#     <tr>
#       <th>Var35</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>14</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var36</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>532</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var37</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>551</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var38</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>30833</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var39</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0.0:50000</td>
#     </tr>
#     <tr>
#       <th>Var40</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>28</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var41</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>37</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var42</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0.0:50000</td>
#     </tr>
#     <tr>
#       <th>Var43</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>21</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var44</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>9</td>
#       <td>0.0:44321<br>0.16683336667333468:5009<br>9.0:562<br>18.0:78<br>27.0:22<br>36.0:5<br>63.0:1<br>72.0:1<br>135.0:1</td>
#     </tr>
#     <tr>
#       <th>Var45</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>344</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var46</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>51</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var47</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>12</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var48</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0.0:50000</td>
#     </tr>
#     <tr>
#       <th>Var49</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>5</td>
#       <td>0.09186140209508462:48759<br>0.0:1225<br>6.0:14<br>18.0:1<br>12.0:1</td>
#     </tr>
#     <tr>
#       <th>Var50</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>64</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var51</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>3562</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var52</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0.0:50000</td>
#     </tr>
#     <tr>
#       <th>Var53</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>398</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var54</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>6</td>
#       <td>4.789685737308622:48759<br>0.0:668<br>8.0:412<br>16.0:153<br>24.0:7<br>32.0:1</td>
#     </tr>
#     <tr>
#       <th>Var55</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0.0:50000</td>
#     </tr>
#     <tr>
#       <th>Var56</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>196</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var57</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>25614</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var58</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>245</td>
#       <td>HC</td>
#     </tr>
#     <tr>
#       <th>Var59</th>
#       <td>float64</td>
#       <td>0</td>
#       <td>567</td>
#       <td>HC</td>
#     </tr>

# %%
#Changing labels to 0 or 1
appetency = (appetency.astype('int') + 1)/2
churn = (churn.astype('int') + 1)/2
upselling = (upselling.astype('int') + 1)/2

# %%
appetency.mean() , churn.mean(), upselling.mean() # Imbalanced data
